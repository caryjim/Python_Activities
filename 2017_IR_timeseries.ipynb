# %% [markdown]
# <a href="https://colab.research.google.com/github/caryjim/Python_Exercise/blob/master/2017_IR_timeseries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.getcwd()
# Out:
# 'D:\\Documents\\PycharmProjects\\LEADING-RAMP'

# %%
import pandas as pd

# %%
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# %%
#list files names in a dir
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir('D:\\Research Data\\LEADING Fellowship\\daily_clicks_per_ir\\first-batch') 
             if isfile(join('D:\\Research Data\\LEADING Fellowship\\daily_clicks_per_ir\\first-batch', f))]

# %%
onlyfiles
# Out:
# ['boston_university_RAMP_pc_daily_clicks.csv',
#  'california_tech_authors_RAMP_pc_daily_clicks.csv',
#  'california_tech_thesis_RAMP_pc_daily_clicks.csv',
#  'kansas_state_university_RAMP_pc_daily_clicks.csv',
#  'maryland_drum_RAMP_pc_daily_clicks.csv',
#  'montana_state_university_RAMP_pc_daily_clicks.csv',
#  'northern_kentucky_university_RAMP_pc_daily_clicks.csv',
#  'rutgers_university_RAMP_pc_daily_clicks.csv',
#  'swarthmore_college_RAMP_pc_daily_clicks.csv',
#  'texas_am_university_RAMP_pc_daily_clicks.csv',
#  'university_kentucky_RAMP_pc_daily_clicks.csv',
#  'university_michigan_RAMP_pc_daily_clicks.csv',
#  'university_nevada_las_vegas_RAMP_pc_daily_clicks.csv',
#  'university_new_mexico_RAMP_pc_daily_clicks.csv',
#  'university_texas_RAMP_pc_daily_clicks.csv']

# %%
# Reference to script from https://www.geeksforgeeks.org/read-multiple-csv-files-into-separate-dataframes-in-python/
# assign dataset names
list_of_names = ['boston_university_RAMP_pc_daily_clicks.csv','california_tech_authors_RAMP_pc_daily_clicks.csv',
                 'california_tech_thesis_RAMP_pc_daily_clicks.csv','kansas_state_university_RAMP_pc_daily_clicks.csv',
                 'maryland_drum_RAMP_pc_daily_clicks.csv','montana_state_university_RAMP_pc_daily_clicks.csv',
                 'northern_kentucky_university_RAMP_pc_daily_clicks.csv','rutgers_university_RAMP_pc_daily_clicks.csv',
                 'swarthmore_college_RAMP_pc_daily_clicks.csv','texas_am_university_RAMP_pc_daily_clicks.csv',
                 'university_kentucky_RAMP_pc_daily_clicks.csv','university_michigan_RAMP_pc_daily_clicks.csv',
                 'university_nevada_las_vegas_RAMP_pc_daily_clicks.csv','university_new_mexico_RAMP_pc_daily_clicks.csv',
                 'university_texas_RAMP_pc_daily_clicks.csv']

# create empty list
dataframes_list = []
 
# append datasets into teh list
for i in range(len(list_of_names)):
    temp_df = pd.read_csv("D:\\Research Data\\LEADING Fellowship\\daily_clicks_per_ir\\first-batch\\"+list_of_names[i], parse_dates = ['date'], index_col = "date")
    dataframes_list.append(temp_df)

# %%
dataframes_list  #Each file has been read as df with date as index, and stored in a list
# Out:
# [            clicks      repository_id
#  date
#  2017-12-17   645.0  boston_university
#  2017-12-18   715.0  boston_university
#  2017-12-19   732.0  boston_university
#  2017-12-20   670.0  boston_university
#  2017-12-21     2.0  boston_university
#  ...            ...                ...
#  2021-03-27   375.0  boston_university
#  2021-03-28   471.0  boston_university
#  2021-03-29   531.0  boston_university
#  2021-03-30   495.0  boston_university
#  2021-03-31   478.0  boston_university
#
#  [1200 rows x 2 columns],
#              clicks            repository_id
#  date
#  2017-12-09    23.0  california_tech_authors
#  2017-12-10    22.0  california_tech_authors
#  2017-12-11    36.0  california_tech_authors
#  2017-12-12    30.0  california_tech_authors
#  2017-12-13    30.0  california_tech_authors
#  ...            ...                      ...
#  2021-03-27  2595.0  california_tech_authors
#  2021-03-28  3040.0  california_tech_authors
#  2021-03-29  3874.0  california_tech_authors
#  2021-03-30  3952.0  california_tech_authors
#  2021-03-31  3881.0  california_tech_authors
#
#  [1209 rows x 2 columns],
#              clicks           repository_id
#  date
#  2017-12-09     4.0  california_tech_thesis
#  2017-12-10     5.0  california_tech_thesis
#  2017-12-11    13.0  california_tech_thesis
#  2017-12-12     9.0  california_tech_thesis
#  2017-12-13     9.0  california_tech_thesis
#  ...            ...                     ...
#  2021-03-27   718.0  california_tech_thesis
#  2021-03-28   738.0  california_tech_thesis
#  2021-03-29  1064.0  california_tech_thesis
#  2021-03-30  1071.0  california_tech_thesis
#  2021-03-31  1030.0  california_tech_thesis
#
#  [1209 rows x 2 columns],
#              clicks            repository_id
#  date
#  2017-04-25   685.0  kansas_state_university
#  2017-04-26  1286.0  kansas_state_university
#  2017-04-27  1184.0  kansas_state_university
#  2017-04-28   912.0  kansas_state_university
#  2017-04-29   699.0  kansas_state_university
#  ...            ...                      ...
#  2021-03-27   760.0  kansas_state_university
#  2021-03-28   936.0  kansas_state_university
#  2021-03-29  1140.0  kansas_state_university
#  2021-03-30  1200.0  kansas_state_university
#  2021-03-31  1144.0  kansas_state_university
#
#  [1432 rows x 2 columns],
#              clicks  repository_id
#  date
#  2017-02-01  3441.0  maryland_drum
#  2017-02-02  3190.0  maryland_drum
#  2017-02-03  2671.0  maryland_drum
#  2017-02-04  1163.0  maryland_drum
#  2017-02-05  1461.0  maryland_drum
#  ...            ...            ...
#  2021-03-27  1521.0  maryland_drum
#  2021-03-28  1804.0  maryland_drum
#  2021-03-29  2300.0  maryland_drum
#  2021-03-30  2256.0  maryland_drum
#  2021-03-31  2007.0  maryland_drum
#
#  [1526 rows x 2 columns],
#              clicks             repository_id
#  date
#  2017-02-01   676.0  montana_state_university
#  2017-02-02   654.0  montana_state_university
#  2017-02-03   623.0  montana_state_university
#  2017-02-04   473.0  montana_state_university
#  2017-02-05   593.0  montana_state_university
#  ...            ...                       ...
#  2021-03-27   720.0  montana_state_university
#  2021-03-28   837.0  montana_state_university
#  2021-03-29   975.0  montana_state_university
#  2021-03-30  1027.0  montana_state_university
#  2021-03-31   966.0  montana_state_university
#
#  [1526 rows x 2 columns],
#              clicks                 repository_id
#  date
#  2017-08-27     3.0  northern_kentucky_university
#  2017-08-28     8.0  northern_kentucky_university
#  2017-10-02    13.0  northern_kentucky_university
#  2017-10-03    10.0  northern_kentucky_university
#  2017-10-04     7.0  northern_kentucky_university
#  ...            ...                           ...
#  2021-03-27    17.0  northern_kentucky_university
#  2021-03-28    19.0  northern_kentucky_university
#  2021-03-29    17.0  northern_kentucky_university
#  2021-03-30    33.0  northern_kentucky_university
#  2021-03-31    28.0  northern_kentucky_university
#
#  [1248 rows x 2 columns],
#              clicks       repository_id
#  date
#  2017-02-01   588.0  rutgers_university
#  2017-02-02   573.0  rutgers_university
#  2017-02-03    68.0  rutgers_university
#  2017-02-04   387.0  rutgers_university
#  2017-02-05   179.0  rutgers_university
#  ...            ...                 ...
#  2021-03-27  1384.0  rutgers_university
#  2021-03-28  1776.0  rutgers_university
#  2021-03-29  1996.0  rutgers_university
#  2021-03-30  1998.0  rutgers_university
#  2021-03-31  1864.0  rutgers_university
#
#  [1518 rows x 2 columns],
#              clicks       repository_id
#  date
#  2017-07-25    75.0  swarthmore_college
#  2017-07-26    70.0  swarthmore_college
#  2017-07-27    61.0  swarthmore_college
#  2017-07-30    68.0  swarthmore_college
#  2017-07-31    80.0  swarthmore_college
#  ...            ...                 ...
#  2021-03-27   193.0  swarthmore_college
#  2021-03-28   344.0  swarthmore_college
#  2021-03-29   406.0  swarthmore_college
#  2021-03-30   390.0  swarthmore_college
#  2021-03-31   397.0  swarthmore_college
#
#  [1340 rows x 2 columns],
#              clicks        repository_id
#  date
#  2017-02-01  1271.0  texas_am_university
#  2017-02-02  1280.0  texas_am_university
#  2017-02-03  1085.0  texas_am_university
#  2017-02-04   747.0  texas_am_university
#  2017-02-05   962.0  texas_am_university
#  ...            ...                  ...
#  2021-03-27  1347.0  texas_am_university
#  2021-03-28  1655.0  texas_am_university
#  2021-03-29  2206.0  texas_am_university
#  2021-03-30  2167.0  texas_am_university
#  2021-03-31  2110.0  texas_am_university
#
#  [1123 rows x 2 columns],
#              clicks        repository_id
#  date
#  2017-07-06  2319.0  university_kentucky
#  2017-07-07  1836.0  university_kentucky
#  2017-07-08  1382.0  university_kentucky
#  2017-07-09  1707.0  university_kentucky
#  2017-07-10  2513.0  university_kentucky
#  ...            ...                  ...
#  2021-03-27  2913.0  university_kentucky
#  2021-03-28  3463.0  university_kentucky
#  2021-03-29  4283.0  university_kentucky
#  2021-03-30  4214.0  university_kentucky
#  2021-03-31  4156.0  university_kentucky
#
#  [1363 rows x 2 columns],
#              clicks        repository_id
#  date
#  2017-02-01  2056.0  university_michigan
#  2017-02-02  1987.0  university_michigan
#  2017-02-03  1520.0  university_michigan
#  2017-02-04  1152.0  university_michigan
#  2017-02-05  1456.0  university_michigan
#  ...            ...                  ...
#  2021-03-27  4635.0  university_michigan
#  2021-03-28  5692.0  university_michigan
#  2021-03-29  6964.0  university_michigan
#  2021-03-30  7060.0  university_michigan
#  2021-03-31  6655.0  university_michigan
#
#  [1525 rows x 2 columns],
#              clicks                repository_id
#  date
#  2017-05-04  1751.0  university_nevada_las_vegas
#  2017-05-05  1291.0  university_nevada_las_vegas
#  2017-05-06   994.0  university_nevada_las_vegas
#  2017-05-07  1290.0  university_nevada_las_vegas
#  2017-05-08  1802.0  university_nevada_las_vegas
#  ...            ...                          ...
#  2021-03-27  2478.0  university_nevada_las_vegas
#  2021-03-28  3083.0  university_nevada_las_vegas
#  2021-03-29  3725.0  university_nevada_las_vegas
#  2021-03-30  3839.0  university_nevada_las_vegas
#  2021-03-31  3522.0  university_nevada_las_vegas
#
#  [1423 rows x 2 columns],
#              clicks          repository_id
#  date
#  2017-02-01  1485.0  university_new_mexico
#  2017-02-02  1336.0  university_new_mexico
#  2017-02-03   928.0  university_new_mexico
#  2017-02-04   739.0  university_new_mexico
#  2017-02-05   951.0  university_new_mexico
#  ...            ...                    ...
#  2021-03-27  4598.0  university_new_mexico
#  2021-03-28  4992.0  university_new_mexico
#  2021-03-29  5849.0  university_new_mexico
#  2021-03-30  5634.0  university_new_mexico
#  2021-03-31  5475.0  university_new_mexico
#
#  [1528 rows x 2 columns],
#              clicks     repository_id
#  date
#  2017-12-11  3380.0  university_texas
#  2017-12-12  3251.0  university_texas
#  2017-12-13  3171.0  university_texas
#  2017-12-14  2961.0  university_texas
#  2017-12-15  2380.0  university_texas
#  ...            ...               ...
#  2021-03-27  2711.0  university_texas
#  2021-03-28  3440.0  university_texas
#  2021-03-29  3768.0  university_texas
#  2021-03-30  3709.0  university_texas
#  2021-03-31  3679.0  university_texas
#
#  [1207 rows x 2 columns]]

# %%
uni_names = ['boston_university_RAMP_pc_daily_clicks','california_tech_authors_RAMP_pc_daily_clicks',
                 'california_tech_thesis_RAMP_pc_daily_clicks','kansas_state_university_RAMP_pc_daily_clicks',
                 'maryland_drum_RAMP_pc_daily_clicks','montana_state_university_RAMP_pc_daily_clicks',
                 'northern_kentucky_university_RAMP_pc_daily_clicks','rutgers_university_RAMP_pc_daily_clicks',
                 'swarthmore_college_RAMP_pc_daily_clicks','texas_am_university_RAMP_pc_daily_clicks',
                 'university_kentucky_RAMP_pc_daily_clicks','university_michigan_RAMP_pc_daily_clicks',
                 'university_nevada_las_vegas_RAMP_pc_daily_clicks','university_new_mexico_RAMP_pc_daily_clicks',
                 'university_texas_RAMP_pc_daily_clicks']

# %%
len(uni_names)
# Out:
# 15

# %%
x = 0
y = 0

# %%
for i in range (0, len(uni_names)):
    x = x+i 
    print(x)
    
    for sch in range(0, len(dataframes_list)):
        y = y+i
        print(i)
        
        uni_names[x] = dataframes_list[y]
        print(uni_names[x])
# Out:
# 0
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 0
#             clicks      repository_id
# date
# 2017-12-17   645.0  boston_university
# 2017-12-18   715.0  boston_university
# 2017-12-19   732.0  boston_university
# 2017-12-20   670.0  boston_university
# 2017-12-21     2.0  boston_university
# ...            ...                ...
# 2021-03-27   375.0  boston_university
# 2021-03-28   471.0  boston_university
# 2021-03-29   531.0  boston_university
# 2021-03-30   495.0  boston_university
# 2021-03-31   478.0  boston_university
#
# [1200 rows x 2 columns]
# 1
# 1
#             clicks            repository_id
# date
# 2017-12-09    23.0  california_tech_authors
# 2017-12-10    22.0  california_tech_authors
# 2017-12-11    36.0  california_tech_authors
# 2017-12-12    30.0  california_tech_authors
# 2017-12-13    30.0  california_tech_authors
# ...            ...                      ...
# 2021-03-27  2595.0  california_tech_authors
# 2021-03-28  3040.0  california_tech_authors
# 2021-03-29  3874.0  california_tech_authors
# 2021-03-30  3952.0  california_tech_authors
# 2021-03-31  3881.0  california_tech_authors
#
# [1209 rows x 2 columns]
# 1
#             clicks           repository_id
# date
# 2017-12-09     4.0  california_tech_thesis
# 2017-12-10     5.0  california_tech_thesis
# 2017-12-11    13.0  california_tech_thesis
# 2017-12-12     9.0  california_tech_thesis
# 2017-12-13     9.0  california_tech_thesis
# ...            ...                     ...
# 2021-03-27   718.0  california_tech_thesis
# 2021-03-28   738.0  california_tech_thesis
# 2021-03-29  1064.0  california_tech_thesis
# 2021-03-30  1071.0  california_tech_thesis
# 2021-03-31  1030.0  california_tech_thesis
#
# [1209 rows x 2 columns]
# 1
#             clicks            repository_id
# date
# 2017-04-25   685.0  kansas_state_university
# 2017-04-26  1286.0  kansas_state_university
# 2017-04-27  1184.0  kansas_state_university
# 2017-04-28   912.0  kansas_state_university
# 2017-04-29   699.0  kansas_state_university
# ...            ...                      ...
# 2021-03-27   760.0  kansas_state_university
# 2021-03-28   936.0  kansas_state_university
# 2021-03-29  1140.0  kansas_state_university
# 2021-03-30  1200.0  kansas_state_university
# 2021-03-31  1144.0  kansas_state_university
#
# [1432 rows x 2 columns]
# 1
#             clicks  repository_id
# date
# 2017-02-01  3441.0  maryland_drum
# 2017-02-02  3190.0  maryland_drum
# 2017-02-03  2671.0  maryland_drum
# 2017-02-04  1163.0  maryland_drum
# 2017-02-05  1461.0  maryland_drum
# ...            ...            ...
# 2021-03-27  1521.0  maryland_drum
# 2021-03-28  1804.0  maryland_drum
# 2021-03-29  2300.0  maryland_drum
# 2021-03-30  2256.0  maryland_drum
# 2021-03-31  2007.0  maryland_drum
#
# [1526 rows x 2 columns]
# 1
#             clicks             repository_id
# date
# 2017-02-01   676.0  montana_state_university
# 2017-02-02   654.0  montana_state_university
# 2017-02-03   623.0  montana_state_university
# 2017-02-04   473.0  montana_state_university
# 2017-02-05   593.0  montana_state_university
# ...            ...                       ...
# 2021-03-27   720.0  montana_state_university
# 2021-03-28   837.0  montana_state_university
# 2021-03-29   975.0  montana_state_university
# 2021-03-30  1027.0  montana_state_university
# 2021-03-31   966.0  montana_state_university
#
# [1526 rows x 2 columns]
# 1
#             clicks                 repository_id
# date
# 2017-08-27     3.0  northern_kentucky_university
# 2017-08-28     8.0  northern_kentucky_university
# 2017-10-02    13.0  northern_kentucky_university
# 2017-10-03    10.0  northern_kentucky_university
# 2017-10-04     7.0  northern_kentucky_university
# ...            ...                           ...
# 2021-03-27    17.0  northern_kentucky_university
# 2021-03-28    19.0  northern_kentucky_university
# 2021-03-29    17.0  northern_kentucky_university
# 2021-03-30    33.0  northern_kentucky_university
# 2021-03-31    28.0  northern_kentucky_university
#
# [1248 rows x 2 columns]
# 1
#             clicks       repository_id
# date
# 2017-02-01   588.0  rutgers_university
# 2017-02-02   573.0  rutgers_university
# 2017-02-03    68.0  rutgers_university
# 2017-02-04   387.0  rutgers_university
# 2017-02-05   179.0  rutgers_university
# ...            ...                 ...
# 2021-03-27  1384.0  rutgers_university
# 2021-03-28  1776.0  rutgers_university
# 2021-03-29  1996.0  rutgers_university
# 2021-03-30  1998.0  rutgers_university
# 2021-03-31  1864.0  rutgers_university
#
# [1518 rows x 2 columns]
# 1
#             clicks       repository_id
# date
# 2017-07-25    75.0  swarthmore_college
# 2017-07-26    70.0  swarthmore_college
# 2017-07-27    61.0  swarthmore_college
# 2017-07-30    68.0  swarthmore_college
# 2017-07-31    80.0  swarthmore_college
# ...            ...                 ...
# 2021-03-27   193.0  swarthmore_college
# 2021-03-28   344.0  swarthmore_college
# 2021-03-29   406.0  swarthmore_college
# 2021-03-30   390.0  swarthmore_college
# 2021-03-31   397.0  swarthmore_college
#
# [1340 rows x 2 columns]
# 1
#             clicks        repository_id
# date
# 2017-02-01  1271.0  texas_am_university
# 2017-02-02  1280.0  texas_am_university
# 2017-02-03  1085.0  texas_am_university
# 2017-02-04   747.0  texas_am_university
# 2017-02-05   962.0  texas_am_university
# ...            ...                  ...
# 2021-03-27  1347.0  texas_am_university
# 2021-03-28  1655.0  texas_am_university
# 2021-03-29  2206.0  texas_am_university
# 2021-03-30  2167.0  texas_am_university
# 2021-03-31  2110.0  texas_am_university
#
# [1123 rows x 2 columns]
# 1
#             clicks        repository_id
# date
# 2017-07-06  2319.0  university_kentucky
# 2017-07-07  1836.0  university_kentucky
# 2017-07-08  1382.0  university_kentucky
# 2017-07-09  1707.0  university_kentucky
# 2017-07-10  2513.0  university_kentucky
# ...            ...                  ...
# 2021-03-27  2913.0  university_kentucky
# 2021-03-28  3463.0  university_kentucky
# 2021-03-29  4283.0  university_kentucky
# 2021-03-30  4214.0  university_kentucky
# 2021-03-31  4156.0  university_kentucky
#
# [1363 rows x 2 columns]
# 1
#             clicks        repository_id
# date
# 2017-02-01  2056.0  university_michigan
# 2017-02-02  1987.0  university_michigan
# 2017-02-03  1520.0  university_michigan
# 2017-02-04  1152.0  university_michigan
# 2017-02-05  1456.0  university_michigan
# ...            ...                  ...
# 2021-03-27  4635.0  university_michigan
# 2021-03-28  5692.0  university_michigan
# 2021-03-29  6964.0  university_michigan
# 2021-03-30  7060.0  university_michigan
# 2021-03-31  6655.0  university_michigan
#
# [1525 rows x 2 columns]
# 1
#             clicks                repository_id
# date
# 2017-05-04  1751.0  university_nevada_las_vegas
# 2017-05-05  1291.0  university_nevada_las_vegas
# 2017-05-06   994.0  university_nevada_las_vegas
# 2017-05-07  1290.0  university_nevada_las_vegas
# 2017-05-08  1802.0  university_nevada_las_vegas
# ...            ...                          ...
# 2021-03-27  2478.0  university_nevada_las_vegas
# 2021-03-28  3083.0  university_nevada_las_vegas
# 2021-03-29  3725.0  university_nevada_las_vegas
# 2021-03-30  3839.0  university_nevada_las_vegas
# 2021-03-31  3522.0  university_nevada_las_vegas
#
# [1423 rows x 2 columns]
# 1
#             clicks          repository_id
# date
# 2017-02-01  1485.0  university_new_mexico
# 2017-02-02  1336.0  university_new_mexico
# 2017-02-03   928.0  university_new_mexico
# 2017-02-04   739.0  university_new_mexico
# 2017-02-05   951.0  university_new_mexico
# ...            ...                    ...
# 2021-03-27  4598.0  university_new_mexico
# 2021-03-28  4992.0  university_new_mexico
# 2021-03-29  5849.0  university_new_mexico
# 2021-03-30  5634.0  university_new_mexico
# 2021-03-31  5475.0  university_new_mexico
#
# [1528 rows x 2 columns]
# 1
#             clicks     repository_id
# date
# 2017-12-11  3380.0  university_texas
# 2017-12-12  3251.0  university_texas
# 2017-12-13  3171.0  university_texas
# 2017-12-14  2961.0  university_texas
# 2017-12-15  2380.0  university_texas
# ...            ...               ...
# 2021-03-27  2711.0  university_texas
# 2021-03-28  3440.0  university_texas
# 2021-03-29  3768.0  university_texas
# 2021-03-30  3709.0  university_texas
# 2021-03-31  3679.0  university_texas
#
# [1207 rows x 2 columns]
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-73-94fad6d4d915> in <module>
#       7         print(i)
#       8
# ----> 9         uni_names[x] = dataframes_list[y]
#      10         print(uni_names[x])
#
# IndexError: list index out of range

# %%
#checking the first IR and if the datatype is correct 
boston = dataframes_list[0]
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1200 entries, 2017-12-17 to 2021-03-31
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   clicks         1200 non-null   float64
#  1   repository_id  1200 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 28.1+ KB

# %%
# !pip install statsmodels

from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse
# Out:
# Requirement already satisfied: statsmodels in d:\program files\python\python38\lib\site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.21 in d:\program files\python\python38\lib\site-packages (from statsmodels) (1.2.2)
# Requirement already satisfied: scipy>=1.1 in d:\program files\python\python38\lib\site-packages (from statsmodels) (1.6.1)
# Requirement already satisfied: patsy>=0.5 in d:\program files\python\python38\lib\site-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: numpy>=1.15 in d:\program files\python\python38\lib\site-packages (from statsmodels) (1.19.3)
# Requirement already satisfied: pytz>=2017.3 in d:\program files\python\python38\lib\site-packages (from pandas>=0.21->statsmodels) (2020.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\program files\python\python38\lib\site-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied: six in d:\program files\python\python38\lib\site-packages (from patsy>=0.5->statsmodels) (1.15.0)
# WARNING: Ignoring invalid distribution -ip (d:\program files\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\program files\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\program files\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\program files\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\program files\python\python38\lib\site-packages)

# %%
# getting length of list
length = len(dataframes_list)

# %%
def plot_series(length):
    for i in range(length):
        data = dataframes_list[i]
        data.sort_index(inplace=True)

        # Additive Decomposition
        add_decomp = seasonal_decompose(data['clicks'], model='additive', extrapolate_trend='freq', period = 7) # for now I'm using 7 for weekly cycle 

        # Multiplicative Decomposition
        # multi_decomp = seasonal_decompose(data['clicks'], model='multiplicative', extrapolate_trend='freq', period = 7) # for now I'm using 7 for weekly cycle 

        #For graphing 
        trend = add_decomp.trend
        seasonal = add_decomp.seasonal
        residual = add_decomp.resid

        # Plot gathered statistics
        plt.figure(figsize=(12,8))
        plt.subplot(411)
        plt.plot(data['clicks'], label='Original', color="blue")
        plt.legend(loc='best')
        plt.subplot(412)
        plt.plot(trend, label='Trend', color="blue")
        plt.legend(loc='best')
        plt.subplot(413)
        plt.plot(seasonal,label='Seasonality', color="blue")
        plt.legend(loc='best')
        plt.subplot(414)
        plt.plot(residual, label='Residuals', color="blue")
        plt.legend(loc='best')
        plt.tight_layout()

        # summary statistics
        print(residual.describe())

        np.mean(residual)

        return

# %%
plot_series(length)
# Out:
# count    1200.000000
# mean        0.082704
# std        84.656598
# min     -1058.203845
# 25%       -40.163024
# 50%         0.055285
# 75%        42.943622
# max       310.551261
# Name: resid, dtype: float64

# %%
# Out:
# <map object at 0x000001E2A609A640>
